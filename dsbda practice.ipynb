# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/HP/OneDrive/Desktop/dataaa.csv')
print(df.head())
# Out:
#    Year  GDP Real (USD)   GDP growth (%)  Per Capita  World Population  \
# 0  2022     9.080000e+13          0.0324       11317        8021407192
# 1  2021     8.790000e+13          0.0635       11054        7954448391
# 2  2020     8.270000e+13         -0.0288       10483        7887001292
# 3  2019     8.510000e+13          0.0268       10898        7811293698
# 4  2018     8.290000e+13          0.0328       10726        7729902781
#
#    Net Change  Population change (%)  Fossil CO2 Emissions (tons)  \
# 0    66958801                 0.0084                  38521997860
# 1    67447099                 0.0086                  38082163770
# 2    75707594                 0.0097                  35944470190
# 3    81390917                 0.0105                  37824905990
# 4    84284827                 0.0110                  37831867370
#
#    CO2 emissions change  CO2 emissions per capita  Population Density (P/Km²)
# ...

# %%
print(df.describe())
# Out:
#               Year  GDP Real (USD)   GDP growth (%)    Per Capita  \
# count    46.000000     4.600000e+01       46.000000     46.000000
# mean   1999.500000     5.097609e+13        0.030350   8006.326087
# std      13.422618     2.013534e+13        0.015413   1720.809526
# min    1977.000000     2.400000e+13       -0.028800   5685.000000
# 25%    1988.250000     3.412500e+13        0.026425   6612.000000
# 50%    1999.500000     4.735000e+13        0.032350   7729.000000
# 75%    2010.750000     6.665000e+13        0.039950   9398.750000
# max    2022.000000     9.080000e+13        0.063500  11317.000000
#
#        World Population    Net Change  Population change (%)  \
# count      4.600000e+01  4.600000e+01              46.000000
# mean       6.128450e+09  8.428610e+07               0.014463
# std        1.150810e+09  5.921616e+06               0.002909
# min        4.217864e+09  6.695880e+07               0.008400
# 25%        5.165102e+09  8.264763e+07               0.012725
# ...

# %%
print(df.isnull().sum())
# Out:
# Year                           0
# GDP Real (USD)                 0
# GDP growth (%)                 0
# Per Capita                     0
# World Population               0
# Net Change                     0
# Population change (%)          0
# Fossil CO2 Emissions (tons)    0
# CO2 emissions change           0
# CO2 emissions per capita       0
# Population Density (P/Km²)     0
# dtype: int64

# %%
df.hist(bins=20, figsize=(10, 8))
plt.suptitle('Histogram of Numerical Features')
plt.show()
